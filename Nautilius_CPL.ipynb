# %% [markdown]
# # CPL Dark Energy Model
#
# This notebook explores the Chevallier-Polarski-Linder (CPL) dark energy parameterisation:
#
# $$w(a) = w_0 + w_a(1-a) = w_0 + w_a\frac{z}{1+z}$$
#
# **Contents**
# 1. Basic evolution checks — $w(z)$, $\Omega_\mathrm{DE}(z)$, $E(z)$
# 2. Distance measures — $D_L(z)$, $\mu(z)$
# 3. Comparison with SNe Ia data (Pantheon 2018)

# %%
import numpy as np
import matplotlib.pyplot as plt
import toolscosmo

plt.rcParams.update({'font.size': 13, 'lines.linewidth': 2.2})

# %% [markdown]
# ## Helper
#
# Always create a **fresh** `par` object per model — reusing the same object and mutating `w0`/`wa` triggered a caching bug (see [sambit-giri/toolscosmo#4](https://github.com/sambit-giri/toolscosmo/issues/4), fixed in `dark-energy-dev`).

# %%
def cpl_par(w0, wa):
    """Return a fresh CPL parameter object with the given (w0, wa)."""
    p = toolscosmo.par(DE='CPL')
    p.DE.w0 = w0
    p.DE.wa = wa
    return p

zs = 10**np.linspace(-3, np.log10(3), 300)  # z in [0.001, 3]

# %% [markdown]
# ## 1. Equation of State $w(z)$

# %%
models = [
    (-1.0,  0.0, '$w_0{=}-1,\, w_a{=}0$ (LCDM)',      'k',  '-'),
    (-0.8,  0.2, '$w_0{=}-0.8,\, w_a{=}0.2$',         'C0', '--'),
    (-1.0, 0.2, '$w_0{=}-1.0,\, w_a{=}-0.2$',        'C1', '-.'),
    (-1.1,  0.0, '$w_0{=}-1.1,\, w_a{=}0.0$',         'C2', ':'),
    (-1.1,  0.3, '$w_0{=}-1.1,\, w_a{=}0.3$',   'C3', (0,(5,2))),
]

fig, ax = plt.subplots(figsize=(7, 4))
for w0, wa, label, color, ls in models:
    w = w0 + wa * zs / (1 + zs)
    ax.semilogx(zs, w, color=color, ls=ls, label=label)
ax.axhline(-1, color='k', lw=0.8, ls='--', alpha=0.4)
ax.set_xlabel('$z$')
ax.set_ylabel('$w(z)$')
ax.set_title('CPL equation of state')
ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Dark Energy Density $\Omega_\mathrm{DE}(z)$
#
# The correct evolution (derived from the continuity equation $\dot\rho = -3H(1+w)\rho$) is
#
# $$\Omega_\mathrm{DE}(z) = \Omega_{\Lambda,0}\, a^{-3(1+w_0+w_a)}\, e^{-3w_a(1-a)}, \qquad a=\frac{1}{1+z}$$

# %%
from toolscosmo.cosmo import Omega_DE

fig, ax = plt.subplots(figsize=(7, 4))
for w0, wa, label, color, ls in models:
    p = cpl_par(w0, wa)
    ODE = np.vectorize(lambda z: Omega_DE(z, p))(zs)
    ax.semilogx(zs, ODE, color=color, ls=ls, label=label)
ax.set_xlabel('$z$')
ax.set_ylabel('$\\Omega_\\mathrm{DE}(z)$')
ax.set_title('Dark energy density evolution')
ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Normalised Hubble Parameter $E(z) = H(z)/H_0$

# %%
fig, ax = plt.subplots(figsize=(7, 4))
for w0, wa, label, color, ls in models:
    p = cpl_par(w0, wa)
    Ez = toolscosmo.Ez_model(p)(zs)
    ax.loglog(zs, Ez, color=color, ls=ls, label=label)
ax.set_xlabel('$z$')
ax.set_ylabel('$E(z)$')
ax.set_title('Normalised Hubble parameter')
ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Distance Modulus $\mu(z)$
#
# $$\mu(z) = 5\log_{10}\!\left[\frac{D_L(z)}{10\,\text{pc}}\right]$$

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

p_lcdm = cpl_par(-1.0, 0.0)
mu_lcdm = toolscosmo.distance_modulus(zs, p_lcdm)

ax = axes[0]
for w0, wa, label, color, ls in models:
    p = cpl_par(w0, wa)
    ax.semilogx(zs, toolscosmo.distance_modulus(zs, p), color=color, ls=ls, label=label)
ax.set_xlabel('$z$')
ax.set_ylabel('$\\mu(z)$')
ax.set_title('Distance modulus')
ax.legend(fontsize=9)

ax = axes[1]
for w0, wa, label, color, ls in models:
    if w0 == -1.0 and wa == 0.0:
        continue
    p = cpl_par(w0, wa)
    dmu = toolscosmo.distance_modulus(zs, p) - mu_lcdm
    ax.semilogx(zs, dmu, color=color, ls=ls, label=label)
ax.axhline(0, color='k', lw=0.8, ls='--', alpha=0.4)
ax.set_xlabel('$z$')
ax.set_ylabel('$\\Delta\\mu(z) = \\mu - \\mu_\\mathrm{LCDM}$')
ax.set_title('Residual vs LCDM')
ax.legend(fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Comparison with SNe Ia Data (Pantheon 2018)
#
# The Pantheon compilation (Scolnic et al. 2018) — 1048 SNe Ia with redshifts $0.01 < z < 2.3$ — is loaded via `toolscosmo.load_sne_data`, which downloads and caches the file on first use.

# %%
sne = toolscosmo.load_sne_data('pantheon')
print(f"Loaded {len(sne['z'])} SNe Ia")

# %%
# mb is the corrected apparent B magnitude; mu = mb - M_B.
# We marginalise over M_B by calibrating each model to the data.
z_sne  = sne['z']
mb     = sne['mu']       # corrected apparent magnitude
dmb    = sne['mu_err']

p_ref  = cpl_par(-1.0, 0.0)
mu_ref = toolscosmo.distance_modulus(z_sne, p_ref)
M_eff  = np.average(mb - mu_ref, weights=1/dmb**2)
mu_obs = mb - M_eff

fig, axes = plt.subplots(2, 1, figsize=(9, 8), sharex=True,
                          gridspec_kw={'height_ratios': [3, 1], 'hspace': 0.05})

ax = axes[0]
ax.errorbar(z_sne, mu_obs, yerr=dmb, fmt='.', color='0.65',
            alpha=0.4, ms=3, elinewidth=0.6, label='Pantheon SNe Ia')
z_th = 10**np.linspace(np.log10(0.01), np.log10(2.4), 400)
for w0, wa, label, color, ls in models:
    p = cpl_par(w0, wa)
    ax.plot(z_th, toolscosmo.distance_modulus(z_th, p), color=color, ls=ls, label=label)
ax.set_ylabel('$\\mu(z)$')
ax.set_title('Distance modulus vs Pantheon 2018 SNe Ia')
ax.legend(fontsize=9, loc='upper left')
ax.set_xlim(0.01, 2.4)

ax = axes[1]
mu_lcdm_sne = toolscosmo.distance_modulus(z_sne, p_ref)
ax.errorbar(z_sne, mu_obs - mu_lcdm_sne, yerr=dmb, fmt='.', color='0.65',
            alpha=0.4, ms=3, elinewidth=0.6)
ax.axhline(0, color='k', lw=1)
for w0, wa, label, color, ls in models:
    if w0 == -1.0 and wa == 0.0:
        continue
    p = cpl_par(w0, wa)
    dmu = toolscosmo.distance_modulus(z_th, p) - toolscosmo.distance_modulus(z_th, p_ref)
    ax.plot(z_th, dmu, color=color, ls=ls)
ax.set_xlabel('$z$')
ax.set_ylabel('$\\Delta\\mu$')
ax.set_ylim(-0.6, 0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Quick $\chi^2$ Summary
#
# A rough goodness-of-fit for each CPL model vs the Pantheon data, ignoring off-diagonal covariances.

# %%
print(f"{'Model':<45} {'chi2/dof':>10}")
print('-' * 57)
ndof = len(z_sne) - 2
for w0, wa, label, color, ls in models:
    p = cpl_par(w0, wa)
    mu_model = toolscosmo.distance_modulus(z_sne, p)
    M_i  = np.average(mb - mu_model, weights=1/dmb**2)
    mu_i = mb - M_i
    chi2 = np.sum(((mu_i - mu_model) / dmb)**2)
    print(f'{label:<45} {chi2/ndof:>10.3f}')

# %%
# Collect chi2/dof values
chi2_dof_values = []
labels = []
for w0, wa, label, color, ls in models:
    p = cpl_par(w0, wa)
    mu_model = toolscosmo.distance_modulus(z_sne, p)
    M_i  = np.average(mb - mu_model, weights=1/dmb**2)
    mu_i = mb - M_i
    chi2 = np.sum(((mu_i - mu_model) / dmb)**2)
    chi2_dof_values.append(chi2 / ndof)
    labels.append(label)

# Plot chi2/dof
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(labels, chi2_dof_values, color=['k', 'C0', 'C1', 'C2', 'C3'])
ax.set_ylabel(r'$\chi^2 / \mathrm{dof}$')
ax.set_title(r'$\chi^2 / \mathrm{dof}$ for different CPL models')
ax.set_xticklabels(labels, rotation=45, ha='right')
for bar, val in zip(bars, chi2_dof_values):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001, f'{val:.3f}', ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Nautilius - Nested sampling

# %%
from scipy.stats import norm
from nautilus import Prior
import numpy as np
from scipy.stats import multivariate_normal


prior = Prior()

prior.add_parameter('w0', dist=(-2.0, 0.0))
prior.add_parameter('wa', dist=(-3.0, 3.0))

# Viktigt: Pantheon har degeneracy mellan H0 och SN absolute magnitude.
# Därför lägger vi till M_shift som nuisance parameter.
prior.add_parameter('M_shift', dist=(-2.0, 2.0))

# %% [markdown]
# ### Model

# %%
import toolscosmo as tcm

def model(param, zz):
    w0, wa = param

    p = tcm.par(DE='CPL')
    p.DE.w0 = w0
    p.DE.wa = wa

    return tcm.distance_modulus(zz, p)

# %% [markdown]
# ### Bringing Pantheon data here to run cells from here and downwards

# %%
# Pantheon data
sne = tcm.load_sne_data('pantheon')
print(f"Loaded {len(sne['z'])} SNe Ia datapoints")

z_sample = sne['z']
mu_sample = sne['mu']        # corrected apparent magnitude / distance modulus-like quantity
dmu_sample = sne['mu_err']
# Out:
# Loaded 1048 SNe Ia datapoints

# %% [markdown]
# ### Sampling

# %%
def likelihood(param_dict):

    w0 = param_dict['w0']
    wa = param_dict['wa']

    param = [w0, wa]

    mu_model = model(param, z_sample)

    delta = mu_sample - mu_model

    chi2 = np.sum((delta / dmu_sample)**2)

    logL = -0.5 * chi2

    return logL

# %%
from nautilus import Sampler

sampler = Sampler(prior, likelihood, n_live=1000)
sampler.run(verbose=True)
# Out:
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Preparing cosmological solvers...        | 0        | 1.0000 | 0     | N/A
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 100      | 1.0000 | 1     | -10663997
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 200      | 1.0000 | 1     | -10663997
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 300      | 1.0000 | 1     | -10663998
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 400      | 1.0000 | 1     | -10663998
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 500      | 1.0000 | 1     | -10663998
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 600      | 1.0000 | 1     | -10663999
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 700      | 1.0000 | 1     | -10647588
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 800      | 1.0000 | 1     | -10647589
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 900      | 1.0000 | 1     | -10647589
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 1000     | 1.0000 | 1     | -10647589
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 1100     | 1.0000 | 1     | -10647589
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# ...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 32400    | 0.9975 | 134   | -10637625
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 32500    | 0.9511 | 590   | -10637630
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 32600    | 0.9957 | 151   | -10637625
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...        | 32700    | 0.9941 | 165   | -10637625
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done
# Preparing cosmological solvers...
# ...done

# %%
import corner
import matplotlib.pyplot as plt

points, log_w, log_l = sampler.posterior()
corner.corner(
    points, weights=np.exp(log_w), bins=20, labels=prior.keys, color='purple',
    plot_datapoints=False, range=np.repeat(0.999, len(prior.keys)))
